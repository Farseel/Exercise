# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Air Conditioners.csv")

# %%
df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category                                              image  \
# 0  Air Conditioners  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  Air Conditioners  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# ...

# %%
df.tail()
# Out:
#                                                   name main_category  \
# 715  Personal Air Conditioners Portable AC Mini Air...    appliances
# 716  Air Conditioner Fan Personal Desk Fan Space Ai...    appliances
# 717  Portable Air Conditioners, Personal Air Condit...    appliances
# 718  Portable Air Conditioner Fan, Personal Air Coo...    appliances
# 719  Air Choice Desktop Protable AC Cooler Fan For ...    appliances
#
#          sub_category                                              image  \
# 715  Air Conditioners  https://m.media-amazon.com/images/I/71RkCzQZyd...
# 716  Air Conditioners  https://m.media-amazon.com/images/I/719ujjLfw7...
# 717  Air Conditioners  https://m.media-amazon.com/images/I/71l59r1G-J...
# 718  Air Conditioners  https://m.media-amazon.com/images/I/61GXC1nOlS...
# 719  Air Conditioners  https://m.media-amazon.com/images/I/71yqMTaaWT...
#
#                                                   link ratings no_of_ratings  \
# ...

# %%
df.sample()
# Out:
#                                                   name main_category  \
# 110  Carrier 1.5 Ton 3 Star Window AC (Copper, Estr...    appliances
#
#          sub_category                                              image  \
# 110  Air Conditioners  https://m.media-amazon.com/images/I/613OvbCF6m...
#
#                                                   link ratings no_of_ratings  \
# 110  https://www.amazon.in/Carrier-Window-Copper-Es...     NaN           NaN
#
#     discount_price actual_price
# 110        ₹35,100      ₹43,090

# %%
df.isna()
# Out:
#       name  main_category  sub_category  image   link  ratings  no_of_ratings  \
# 0    False          False         False  False  False    False          False
# 1    False          False         False  False  False    False          False
# 2    False          False         False  False  False    False          False
# 3    False          False         False  False  False    False          False
# 4    False          False         False  False  False    False          False
# ..     ...            ...           ...    ...    ...      ...            ...
# 715  False          False         False  False  False     True           True
# 716  False          False         False  False  False     True           True
# 717  False          False         False  False  False     True           True
# 718  False          False         False  False  False    False          False
# 719  False          False         False  False  False    False          False
#
# ...

# %%
df.isna().sum()
# Out:
# name                0
# main_category       0
# sub_category        0
# image               0
# link                0
# ratings           287
# no_of_ratings     287
# discount_price    263
# actual_price      220
# dtype: int64

# %%
df.nunique()
# Out:
# name              708
# main_category       1
# sub_category        1
# image             635
# link              720
# ratings            31
# no_of_ratings     187
# discount_price    295
# actual_price      296
# dtype: int64

# %%
df=df.drop(["main_category","sub_category"],axis=1)

# %%
df.head()
# Out:
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2         2,255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2         2,948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...     4.2         1,206
# ...

# %%
df.isna().sum()
# Out:
# name                0
# image               0
# link                0
# ratings           287
# no_of_ratings     287
# discount_price    263
# actual_price      220
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            720 non-null    object
#  1   image           720 non-null    object
#  2   link            720 non-null    object
#  3   ratings         433 non-null    object
#  4   no_of_ratings   433 non-null    object
#  5   discount_price  457 non-null    object
#  6   actual_price    500 non-null    object
# dtypes: object(7)
# memory usage: 39.5+ KB

# %%
df["ratings"]=df["ratings"].fillna(0.0)

# %%
df.isna().sum()
# Out:
# name                0
# image               0
# link                0
# ratings             0
# no_of_ratings     287
# discount_price    263
# actual_price      220
# dtype: int64

# %%
df["no_of_ratings"]=df["no_of_ratings"].fillna("0")
df["discount_price"]=df["discount_price"].fillna("0.0")
df["actual_price"]=df["actual_price"].fillna("0.0")

# %%
df.isna().sum()
# Out:
# name              0
# image             0
# link              0
# ratings           0
# no_of_ratings     0
# discount_price    0
# actual_price      0
# dtype: int64

# %%
df.loc[df["ratings"]=='Get',:]
# Out:
#                                                   name  \
# 437  Daikin 1.8 Ton 3 Star Inverter Split Ac (Coppe...
# 473  Master Electronic provides Window AC 3-Star 1....
# 474  Master Electronic provides 1.5 Ton 3 Star Dust...
# 475  Master Electronics Provides 1 Ton 3 Star Inver...
# 488            1.5 Ton 5 Star Inverter Split AC, White
# 499  SUHANA snow falls Best 5 Star 1.5 Ton Air Cond...
# 582  MEGACOOL CENTRE-Dakin 1.5 Ton 3 Star Fixed Spe...
# 595        Heavy Duty Air Conditioner Outdoor Ac stand
# 639  Blue Star 1.5 Tr 3 Star Fixed Speed Split AC (...
# 643  Daikin 1.8 Ton 3 Star Inverter Split AC (Coppe...
#
#                                                  image  \
# 437  https://m.media-amazon.com/images/I/51hn7NHS3T...
# 473  https://m.media-amazon.com/images/I/41B0LWORAr...
# 474  https://m.media-amazon.com/images/I/61yVE5P7FU...
# 475  https://m.media-amazon.com/images/I/11mMBc5fl2...
# 488  https://m.media-amazon.com/images/I/11au-UO4sB...
# ...

# %%
df.loc[df["ratings"]=='Get',"ratings"]="0.0"

# %%
df["actual_price"]=df["actual_price"].str.replace(",","")

# %%
df["discount_price"]=df["discount_price"].str.replace(",","")

# %%
df["no_of_ratings"]=df["no_of_ratings"].str.replace(",","")

# %%
df["discount_price"]=df["discount_price"].str.replace("₹","")

# %%
df["actual_price"]=df["actual_price"].str.replace("₹","")

# %%
df.loc[df["ratings"]=='Get',:]
# Out:
# Empty DataFrame
# Columns: [name, image, link, ratings, no_of_ratings, discount_price, actual_price]
# Index: []

# %%
df.head()
# Out:
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2          2255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2          2948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...     4.2          1206
# ...

# %%
df["ratings"]=df["ratings"].astype(float)
df["discount_price"]=df["discount_price"].astype(float)
df["actual_price"]=df["actual_price"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            720 non-null    object
#  1   image           720 non-null    object
#  2   link            720 non-null    object
#  3   ratings         720 non-null    float64
#  4   no_of_ratings   720 non-null    object
#  5   discount_price  720 non-null    float64
#  6   actual_price    720 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 39.5+ KB

# %%
df["no_of_ratings"].unique()
# Out:
# array(['2255', '2948', '1206', '69', '630', '1666', '1097', '1494', '674',
#        '801', '558', '730', '5073', '568', '3670', '312', '88', '432',
#        '268', '2', '700', '540', '258', '2178', '0', '1444', '360', '38',
#        '1208', '341', '3', '15', '925', '3604', '42', '22', '94', '1866',
#        '292', '1830', '8', '536', '201', '2722', '202', '23', '1195', '5',
#        '66', '474', '502', '686', '1183', '56', '1', '49', '212', '79',
#        '468', '317', '45', '142', '451', '145', '265', '3157', '274',
#        '39', '178', '655', '81', '43', '234', '134', '97', '229', '12',
#        '748', '926', '62', '14', '440', '85', '260', '118', '172', '387',
#        '195', '7', '158', '9', '10', '1295', '16', '303', '120', '55',
#        '27', '34', '37', '1573', '29', '6', '112', '200', '11', '121',
#        '886', '209', '4', '207', '622', '31', '192', '40', '101', '96',
#        '70', '259', '1400', '288', '13', '51', '175', '114', '567', '187',
# ...

# %%
df.loc[df["no_of_ratings"]== 'Only 2 left in stock.',:]
# Out:
#                                                   name  \
# 437  Daikin 1.8 Ton 3 Star Inverter Split Ac (Coppe...
# 488            1.5 Ton 5 Star Inverter Split AC, White
# 595        Heavy Duty Air Conditioner Outdoor Ac stand
#
#                                                  image  \
# 437  https://m.media-amazon.com/images/I/51hn7NHS3T...
# 488  https://m.media-amazon.com/images/I/11au-UO4sB...
# 595  https://m.media-amazon.com/images/I/51mvmI9NjU...
#
#                                                   link  ratings  \
# 437  https://www.amazon.in/Daikin-Inverter-Copper-F...      0.0
# 488  https://www.amazon.in/1-5-Star-Inverter-Split-...      0.0
# 595  https://www.amazon.in/Heavy-Duty-Conditioner-O...      0.0
#
#              no_of_ratings  discount_price  actual_price
# 437  Only 2 left in stock.         59979.0       72900.0
# 488  Only 2 left in stock.         45000.0       50000.0
# 595  Only 2 left in stock.           899.0        1750.0

# %%
df.loc[df["no_of_ratings"]== 'Only 1 left in stock.',:]
# Out:
#                                                   name  \
# 473  Master Electronic provides Window AC 3-Star 1....
# 474  Master Electronic provides 1.5 Ton 3 Star Dust...
# 475  Master Electronics Provides 1 Ton 3 Star Inver...
# 499  SUHANA snow falls Best 5 Star 1.5 Ton Air Cond...
# 582  MEGACOOL CENTRE-Dakin 1.5 Ton 3 Star Fixed Spe...
# 639  Blue Star 1.5 Tr 3 Star Fixed Speed Split AC (...
# 643  Daikin 1.8 Ton 3 Star Inverter Split AC (Coppe...
#
#                                                  image  \
# 473  https://m.media-amazon.com/images/I/41B0LWORAr...
# 474  https://m.media-amazon.com/images/I/61yVE5P7FU...
# 475  https://m.media-amazon.com/images/I/11mMBc5fl2...
# 499  https://m.media-amazon.com/images/I/31QQZehTYc...
# 582  https://m.media-amazon.com/images/I/21pJ7D2fWm...
# 639  https://m.media-amazon.com/images/I/31Tci462W1...
# 643  https://m.media-amazon.com/images/I/61+ky9zVBZ...
#
#                                                   link  ratings  \
# ...

# %%
df.loc[df["no_of_ratings"]== 'Only 1 left in stock.',"no_of_ratings"]="0"
df.loc[df["no_of_ratings"]== 'Only 2 left in stock.',"no_of_ratings"]="0"

# %%
df["no_of_ratings"]=df["no_of_ratings"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            720 non-null    object
#  1   image           720 non-null    object
#  2   link            720 non-null    object
#  3   ratings         720 non-null    float64
#  4   no_of_ratings   720 non-null    int64
#  5   discount_price  720 non-null    float64
#  6   actual_price    720 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 39.5+ KB

# %%
avg_no_of_ratings=df.loc[df["no_of_ratings"]!=0,"no_of_ratings"].mean()

# %%
avg_no_of_ratings
# Out:
# np.float64(245.22458628841608)

# %%
df.loc[df["no_of_ratings"]==0,"no_of_ratings"]=avg_no_of_ratings.astype(int)

# %%
df["no_of_ratings"].unique()
# Out:
# array([2255, 2948, 1206,   69,  630, 1666, 1097, 1494,  674,  801,  558,
#         730, 5073,  568, 3670,  312,   88,  432,  268,    2,  700,  540,
#         258, 2178,  245, 1444,  360,   38, 1208,  341,    3,   15,  925,
#        3604,   42,   22,   94, 1866,  292, 1830,    8,  536,  201, 2722,
#         202,   23, 1195,    5,   66,  474,  502,  686, 1183,   56,    1,
#          49,  212,   79,  468,  317,   45,  142,  451,  145,  265, 3157,
#         274,   39,  178,  655,   81,   43,  234,  134,   97,  229,   12,
#         748,  926,   62,   14,  440,   85,  260,  118,  172,  387,  195,
#           7,  158,    9,   10, 1295,   16,  303,  120,   55,   27,   34,
#          37, 1573,   29,    6,  112,  200,   11,  121,  886,  209,    4,
#         207,  622,   31,  192,   40,  101,   96,   70,  259, 1400,  288,
#          13,   51,  175,  114,  567,  187,   21, 1832,  563,   24,  769,
#         542,  297,  329,   20,  156,   26,  485, 9577,  302,  255, 1420,
# ...

# %%
avg_ratings=df.loc[df["ratings"]!=0.0,"ratings"].mean().round(1)
avg_ratings
# Out:
# np.float64(3.8)

# %%
df.loc[df["ratings"]==0.0,"ratings"]=avg_ratings

# %%
df["ratings"].unique()
# Out:
# array([4.2, 4. , 4.1, 4.3, 3.9, 3.8, 3.5, 4.6, 3.3, 3.4, 3.7, 2.9, 5. ,
#        4.4, 3.6, 2.7, 4.5, 3. , 3.1, 3.2, 4.8, 4.7, 2.5, 1. , 2.6, 2.8,
#        2.3, 1.7, 1.8, 2.4])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            720 non-null    object
#  1   image           720 non-null    object
#  2   link            720 non-null    object
#  3   ratings         720 non-null    float64
#  4   no_of_ratings   720 non-null    int64
#  5   discount_price  720 non-null    float64
#  6   actual_price    720 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 39.5+ KB

# %%
avg_discount_price=df.loc[df["discount_price"]!=0.0,"discount_price"].mean().round(1)
avg_discount_price
# Out:
# np.float64(40756.0)

# %%
df.loc[df["discount_price"]==0.0,"discount_price"]=avg_discount_price

# %%
df["discount_price"].unique()
# Out:
# array([ 32999.,  46490.,  34490.,  37990.,  31990.,  29999.,  39990.,
#         30990.,  37999.,  32990.,  44990.,  45990.,  41999.,  35499.,
#         34000.,  37490.,  29490.,  39499.,  35990.,  33490.,  42490.,
#         27440.,  43599.,  36700.,  31999.,  32480.,  32490.,  37699.,
#         29990.,  38990.,  27490.,  30490.,  38499.,  26490.,  34699.,
#         37800.,  44477.,  28990.,  52990.,  32690.,  29950.,  36999.,
#         48990.,  25690.,  42240.,  52090.,  46499.,  42990.,  30399.,
#         34990.,  40618.,  49349.,  46000.,  27499.,  57379.,  29799.,
#         52900.,  40756.,  25990.,  33950.,  36990.,  44490.,  53490.,
#         35385.,  24990.,  27990.,  56990.,  66990.,  48000.,  33900.,
#         26950.,  48567.,  43990.,  36490.,  33678.,  38890.,  43890.,
#         28180.,  49990.,   2499.,  35750.,  54490.,  35100.,  31500.,
#         25490.,  58890.,  52499.,  37290.,  47490.,  45790.,  63490.,
# ...

# %%
avg_actual_price=df.loc[df["actual_price"]!=0.0,"actual_price"].mean().round(1)
avg_actual_price
# Out:
# np.float64(54815.2)

# %%
df.loc[df["actual_price"]==0.0,"actual_price"]=avg_actual_price

# %%
df["actual_price"].unique()
# Out:
# array([ 58990.  ,  75990.  ,  61990.  ,  68990.  ,  67790.  ,  70990.  ,
#         49990.  ,  67990.  ,  58190.  ,  73990.  ,  48200.  ,  67200.  ,
#         63400.  ,  78490.  ,  62000.  ,  60990.  ,  57990.  ,  54900.  ,
#         42900.  ,  58400.  ,  62250.  ,  62990.  ,  71990.  ,  54600.  ,
#         47990.  ,  72990.  ,  50990.  ,  46900.  ,  79990.  ,  57700.  ,
#         70600.  ,  54990.  ,  55500.  ,  39000.  ,  33000.  ,  55400.  ,
#         53990.  ,  55600.  ,  45090.  ,  47790.  ,  41500.  ,  91690.  ,
#         51500.  ,  52900.  ,  56990.  ,  80890.  ,  43990.  ,  48100.  ,
#         64200.  ,  64000.  ,  71900.  ,  85990.  ,  59400.  ,  39500.  ,
#         44500.  ,  47100.  ,  49089.  ,  42190.  ,  69990.  ,  77990.  ,
#         46990.  ,  93990.  ,  42990.  ,  54815.2 ,  49000.  ,  50600.  ,
#         73000.  ,  83990.  ,  78990.  ,  56179.  ,  59700.  ,  30000.  ,
#         29490.  ,  40900.  ,  77150.  ,  87900.  ,  71750.  ,  59990.  ,
# ...

# %%
df.head()
# Out:
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2           2255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2           2948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2           1206
# ...

# %%
df["brand_name"]=df["name"].str.split(" ").str[0]

# %%
df.head()
# Out:
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2           2255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2           2948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2           1206
# ...

# %%
df["ton"]=df["name"].str.split(" ").str[1]

# %%
df.head()
# Out:
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2           2255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2           2948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2           1206
# ...

# %%
df["electricity_stars"]=df["name"].str.split(" ").str[3]

# %%
df.head()
# Out:
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2           2255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2           2948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2           1206
# ...

# %%
df["brand_name"].unique()
# Out:
# array(['Lloyd', 'LG', 'Carrier', 'Voltas', 'Daikin', 'Panasonic',
#        'Whirlpool', 'Samsung', 'Godrej', 'Blue', 'IFB', 'Cruise',
#        'AmazonBasics', 'Haier', 'Hitachi', 'Amazon', 'OGENERAL', 'Small',
#        'ALLWIN', 'Hexzone', 'Candy', 'O-General', 'ONIDA', 'Portable',
#        'AC', 'Ogeneral', 'MITSUBISHI', 'Nutricook', 'Hisense', 'ThreeH',
#        'OGeneral', 'Mitsubishi', 'FANCISUN', 'BENBOAR', 'O', 'FIDEL',
#        'smartmi', 'Ontel', 'Hexzone®', 'CARRIER', 'Window', 'Symphony',
#        'Rechargeable', 'Equator', 'Midea', 'SPLIT', 'Supreme', 'TOSHIBA',
#        'Kelvinator', 'DotOne', 'HITACHI', 'Vestar', 'DAIKIN', 'Comfee',
#        'RISARYA', 'Personal', 'Havells-Lloyd', 'Onida', 'Livpure', 'TCL',
#        'Voltas\xa0Venture\xa0i\xa0Cassette\xa03Ph\xa0Scroll\xa0SAC(C2-N)',
#        'Electrolux', '1', 'Raptor', 'QAWACHH', 'CS/CU-KU12YKYF', 'VESTAR',
#        'Master', '1.5', 'White', 'WINDOW', 'SUHANA', 'Vukar', 'Kwality',
# ...

# %%
df["ton"].unique()
# Out:
# array(['1.5', '1', '1.4', '1.0', 'Star', '2', '0.8', 'Split', '2.0',
#        'Basics', 'SAC', 'SPLIT', 'AMGB09BAWA-B', 'Personal', '1.8',
#        'TAFTA', 'Floor', 'Air', '1.25', 'Stand/Heavy', 'Frost', 'HEAVY',
#        '2.02', 'USB', '2.2', 'AXGB18BAWA', 'Heavy', 'Wash', '1.51066',
#        'Portable', 'Havells', 'general', 'Tafta', 'Adjustable', 'Venture',
#        '1.6', 'Arctic', 'Emperia', '1.2', 'AC', 'Diet', '220V/950W',
#        'ASGA24BMWA', 'DUAL', '183', 'Cool', 'General', 'ASGA18BMWA',
#        'Estrella', 'RKM60TV16UC', '-', 'Convertible', 'FTHT50TV16',
#        'H20R1203', 'ESTRELLA', 'Supreme', '18k', 'Super', '183V',
#        'Durawhite', 'CPTB', '12K', 'AXGB24BAWA', 'All', '(3', 'Ton',
#        '1.1', '3', 'ZUNOH', 'Panasonic', '3Ph', '24HY', 'WindFree',
#        '1.5Ton', '1.0Ton', '1.Ton', 'Electronic', 'Electronics',
#        'outdoor', 'PS-Q19ENYE', 'AI+', 'AI', 'Window', 'Westinghouse',
#        'snow', '-15F.1-1S01-', '-10H.1-3S01-', '-10V.1-3S01-',
# ...

# %%
df["electricity_stars"].unique()
# Out:
# array(['3', '5', '4', 'Ton', '2', '-', 'Ton,', '[Portable', 'Vectra',
#        'AC', 'Conditioners', 'Quality', 'Stand', 'Air', '1.5', 'Inverter',
#        'SRK25CSS-S6', 'Conditioner|2', 'Mini,', 'Tr', 'Silent',
#        'Antibacterial', '1.6', 'Conditioner,Personal', 'Conditioner',
#        'Duty', 'for', 'AC,', 'Tower', 'SRK13CRS', 'Freedom', 'Wifi',
#        'Hot', 'Ac', '1', '22', 'Outdoor', 'Window', 'Conditioner|1.5',
#        '2.0', '1.5T', '2.2', '18K', 'Rot.', 'FTKM60TV16UC', 'BEE',
#        '1.0TR', 'USB', '1PCS', 'Conditioner|1', 'Xpand', 'Portable',
#        'Star', 'Split', '1.5TR', '24K', 'CX', 'Cx', nan, 'Super', 'Motor',
#        'SAC', 'and', '6-in-1,', 'ton', 'Best', 'Voltage', '1.0',
#        'Generic', 'Conditioning', 'SR123SS', 'Ultra', 'Long', 'Savings',
#        'APPLIANCES', 'Speed', 'TOWER', 'Size', 'Non-Inverter', 'Kashmir',
#        '1.8TR', 'with', '2.0TON', '1.0Ton', '2.0Ton', 'Fan',
# ...

# %%
df["more_info"]=df["name"].str.split(" ").str[4:]

# %%
df.columns
# Out:
# Index(['name', 'image', 'link', 'ratings', 'no_of_ratings', 'discount_price',
#        'actual_price', 'brand_name', 'ton', 'electricity_stars', 'more_info'],
#       dtype='object')

# %%
df=df[['brand_name', 'ton', 'electricity_stars', 'ratings', 'no_of_ratings', 'discount_price',
       'actual_price', 'more_info', 'image', 'link']]

# %%
df.head()
# Out:
#   brand_name  ton electricity_stars  ratings  no_of_ratings  discount_price  \
# 0      Lloyd  1.5                 3      4.2           2255         32999.0
# 1         LG  1.5                 5      4.2           2948         46490.0
# 2         LG    1                 4      4.2           1206         34490.0
# 3         LG  1.5                 3      4.0             69         37990.0
# 4    Carrier  1.5                 3      4.1            630         34490.0
#
#    actual_price                                          more_info  \
# 0       58990.0  [Star, Inverter, Split, Ac, (5, In, 1, Convert...
# 1       75990.0  [Star, AI, DUAL, Inverter, Split, AC, (Copper,...
# 2       61990.0  [Star, Ai, Dual, Inverter, Split, Ac, (Copper,...
# 3       68990.0  [Star, AI, DUAL, Inverter, Split, AC, (Copper,...
# 4       67790.0  [Star, Inverter, Split, AC, (Copper,ESTER, Dxi...
#
#                                                image  \
# ...

# %%
df["link"][0]
# Out:
# 'https://www.amazon.in/Lloyd-Inverter-Convertible-Anti-Viral-GLS18I3FWAMC/dp/B0BRKXTSBT/ref=sr_1_4?qid=1679134237&s=kitchen&sr=1-4'

# %%
df.to_csv("cleaned_ac_data.csv")
