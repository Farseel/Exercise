# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("cleaning_ex3.csv")

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          660 non-null    object
#  1   Salary Estimate    660 non-null    object
#  2   Job Description    660 non-null    object
#  3   Rating             660 non-null    float64
#  4   Company Name       660 non-null    object
#  5   Location           660 non-null    object
#  6   Headquarters       660 non-null    object
#  7   Size               660 non-null    object
#  8   Type of ownership  660 non-null    object
#  9   Industry           660 non-null    object
#  10  Sector             660 non-null    object
#  11  Revenue            660 non-null    object
#  12  company_age        660 non-null    int64
#  13  seniority          660 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 72.3+ KB

# %%
df["Size"].unique()
# Out:
# array(['1001 to 5000 employees', '5001 to 10000 employees',
#        '501 to 1000 employees', '51 to 200 employees', '10000+ employees',
#        '201 to 500 employees', '1 to 50 employees', '-1', 'Unknown'],
#       dtype=object)

# %%
df.loc[df["Size"]=="-1","Size"]="0 to 0 employees"

# %%
df.loc[df["Size"]=="Unknown","Size"]="0 to 0 employees"

# %%
df.loc[df["Size"]=="10000+ employees","Size"]="10000 to 10000+ employees"

# %%
df["Size"].unique()
# Out:
# array(['1001 to 5000 employees', '5001 to 10000 employees',
#        '501 to 1000 employees', '51 to 200 employees',
#        '10000 to 10000+ employees', '201 to 500 employees',
#        '1 to 50 employees', '0 to 0 employees'], dtype=object)

# %%
df["min_employees"]=df["Size"].str.split(" ").str[0]

# %%
df[["Company Name","min_employees"]]
# Out:
#              Company Name min_employees
# 0             Healthfirst          1001
# 1                 ManTech          5001
# 2          Analysis Group          1001
# 3                 INFICON           501
# 4      Affinity Solutions            51
# ..                    ...           ...
# 655              TRANZACT          1001
# 656                  JKGT             0
# 657            AccessHope             0
# 658  ChaTeck Incorporated             1
# 659         1-800-Flowers          1001
#
# [660 rows x 2 columns]

# %%
df["Company Name"].nunique()
# Out:
# 425

# %%
df["Revenue"].unique()
# Out:
# array(['Unknown / Non-Applicable', '$1 to $2 billion (USD)',
#        '$100 to $500 million (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$500 million to $1 billion (USD)',
#        '$5 to $10 billion (USD)', '$10 to $25 million (USD)',
#        '$25 to $50 million (USD)', '$50 to $100 million (USD)',
#        '$1 to $5 million (USD)', '$5 to $10 million (USD)', '-1',
#        'Less than $1 million (USD)'], dtype=object)

# %%
df.loc[df["Revenue"]=="Unknown / Non-Applicable","Revenue"]="$1 million (USD)"

# %%
df.loc[df["Revenue"]=="-1","Revenue"]="$1 million (USD)"

# %%
df["Revenue"].unique()
# Out:
# array(['$1 million (USD)', '$1 to $2 billion (USD)',
#        '$100 to $500 million (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$500 million to $1 billion (USD)',
#        '$5 to $10 billion (USD)', '$10 to $25 million (USD)',
#        '$25 to $50 million (USD)', '$50 to $100 million (USD)',
#        '$1 to $5 million (USD)', '$5 to $10 million (USD)',
#        'Less than $1 million (USD)'], dtype=object)

# %%
df["Salary Estimate"].unique()
# Out:
# array(['137-171 ', '75-131 ', '79-131 ', '99-132 ', '90-109 ', '101-165 ',
#        '56-97 ', '79-106 ', '71-123 ', '90-124 ', '91-150 ', '141-225 ',
#        '145-225', '79-147 ', '122-146 ', '112-116 ', '110-163 ',
#        '124-198 ', '79-133 ', '69-116 ', '31-56 ', '95-119 ', '212-331 ',
#        '66-112 ', '128-201 ', '138-158 ', '80-132 ', '87-141 ', '92-155 ',
#        '105-167 '], dtype=object)

# %%
df["min_salary"]=df["Salary Estimate"].str.replace(" ","").str.split("-").str[0]

# %%
df["max_salary"]=df["Salary Estimate"].str.replace(" ","").str.split("-").str[1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          660 non-null    object
#  1   Salary Estimate    660 non-null    object
#  2   Job Description    660 non-null    object
#  3   Rating             660 non-null    float64
#  4   Company Name       660 non-null    object
#  5   Location           660 non-null    object
#  6   Headquarters       660 non-null    object
#  7   Size               660 non-null    object
#  8   Type of ownership  660 non-null    object
#  9   Industry           660 non-null    object
#  10  Sector             660 non-null    object
#  11  Revenue            660 non-null    object
#  12  company_age        660 non-null    int64
#  13  seniority          660 non-null    object
#  14  min_employees      660 non-null    object
#  15  min_salary         660 non-null    object
# ...

# %%
df["max_salary"]=df["max_salary"].astype(int)

# %%
df["min_salary"]=df["min_salary"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          660 non-null    object
#  1   Salary Estimate    660 non-null    object
#  2   Job Description    660 non-null    object
#  3   Rating             660 non-null    float64
#  4   Company Name       660 non-null    object
#  5   Location           660 non-null    object
#  6   Headquarters       660 non-null    object
#  7   Size               660 non-null    object
#  8   Type of ownership  660 non-null    object
#  9   Industry           660 non-null    object
#  10  Sector             660 non-null    object
#  11  Revenue            660 non-null    object
#  12  company_age        660 non-null    int64
#  13  seniority          660 non-null    object
#  14  min_employees      660 non-null    object
#  15  min_salary         660 non-null    int64
# ...

# %%
df["avg_salary"]=(df["min_salary"]+df["max_salary"])/2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          660 non-null    object
#  1   Salary Estimate    660 non-null    object
#  2   Job Description    660 non-null    object
#  3   Rating             660 non-null    float64
#  4   Company Name       660 non-null    object
#  5   Location           660 non-null    object
#  6   Headquarters       660 non-null    object
#  7   Size               660 non-null    object
#  8   Type of ownership  660 non-null    object
#  9   Industry           660 non-null    object
#  10  Sector             660 non-null    object
#  11  Revenue            660 non-null    object
#  12  company_age        660 non-null    int64
#  13  seniority          660 non-null    object
#  14  min_employees      660 non-null    object
#  15  min_salary         660 non-null    int64
# ...

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df[['Company Name','min_salary',	'max_salary',	'avg_salary']]
# Out:
#              Company Name  min_salary  max_salary  avg_salary
# 0             Healthfirst         137         171       154.0
# 1                 ManTech         137         171       154.0
# 2          Analysis Group         137         171       154.0
# 3                 INFICON         137         171       154.0
# 4      Affinity Solutions         137         171       154.0
# ..                    ...         ...         ...         ...
# 655              TRANZACT         105         167       136.0
# 656                  JKGT         105         167       136.0
# 657            AccessHope         105         167       136.0
# 658  ChaTeck Incorporated         105         167       136.0
# 659         1-800-Flowers         105         167       136.0
#
# [660 rows x 4 columns]

# %%
df["Location"].unique()
# Out:
# array(['New York, NY', 'Chantilly, VA', 'Boston, MA', 'Newton, MA',
#        'Santa Barbara, CA', 'Cambridge, MA', 'Bedford, MA',
#        'San Diego, CA', 'Chicago, IL', 'Herndon, VA', 'Saint Louis, MO',
#        'Richland, WA', 'Northbrook, IL', 'Washington, DC', 'Memphis, TN',
#        'Plano, TX', 'West Grove, PA', 'Phoenix, AZ', 'Appleton, WI',
#        'Atlanta, GA', 'Orlando, FL', 'Lexington, MA', 'McLean, VA',
#        'San Francisco, CA', 'Sheboygan, WI', 'United States',
#        'Bothell, WA', 'Lincoln, NE', 'Overland Park, KS',
#        'Santa Monica, CA', 'Portsmouth, NH', 'Ewing, NJ',
#        'South San Francisco, CA', 'Palo Alto, CA', 'Bellevue, WA',
#        'New Orleans, LA', 'Akron, OH', 'Fort Wayne, IN', 'Woburn, MA',
#        'Carson, CA', 'Coral Gables, FL', 'Santa Clara, CA',
#        'Brisbane, CA', 'Winter Park, FL', 'Redwood City, CA',
#        'Peoria, IL', 'Ipswich, MA', 'Carmel, IN', 'Emeryville, CA',
# ...

# %%
df["province_loc"]=df["Location"].str.replace(" ","").str.split(",").str[-1]

# %%
df["state_loc"]=df["Location"].str.replace(" ","").str.split(",").str[0]

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df["Headquarters"].unique()
# Out:
# array(['New York, NY', 'Herndon, VA', 'Boston, MA',
#        'Bad Ragaz, Switzerland', 'Santa Barbara, CA',
#        'Basel, Switzerland', 'Bedford, MA', 'Mountain View, CA',
#        'Chicago, IL', 'Mc Lean, VA', 'Saint Louis, MO', 'Richland, WA',
#        'Northbrook, IL', 'Princeton, NJ', 'Mays Landing, NJ',
#        'Memphis, TN', 'Tempe, AZ', 'Reading, PA', 'San Francisco, CA',
#        'Menlo Park, CA', 'Atlanta, GA', 'Orlando, FL', 'Lexington, MA',
#        'Falls Church, VA', 'Sheboygan, WI', 'Seattle, WA', 'Bellevue, WA',
#        'Lincoln, NE', 'Chantilly, VA', 'Santa Monica, CA', 'Ewing, NJ',
#        'South San Francisco, CA', 'Palo Alto, CA', 'Singapore, Singapore',
#        'Cambridge, MA', 'OSAKA, Japan', 'Santa Clara, CA',
#        'New Orleans, LA', 'Akron, OH', 'Zurich, Switzerland',
#        'Woburn, MA', 'Carson, CA', 'Coral Gables, FL', 'San Ramon, CA',
#        'Brisbane, CA', 'Winter Park, FL', 'San Rafael, CA',
# ...

# %%
df.loc[df['Headquarters']=="-1","Headquarters"]=df["Location"]

# %%
df["province_hq"]=df["Headquarters"].str.replace(" ","").str.split(",").str[-1]

# %%
df["state_hq"]=df["Headquarters"].str.replace(" ","").str.split(",").str[0]

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...
